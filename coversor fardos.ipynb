# %%
def fardo_a_unidades(fa):
  fardo= 5
  return fa

  def unidades_a_fardo(und):
    unidades= 28
    return und

    print ("1 Convertir fardo a unidades")
    print ("2 Convertir unidades a fardo")
    opcion = input ("-->")

    op = menu ()
    if op== "1":
      cjas = float(input("introduce numero de fardos:   "))
      conversion = fardo_a_unidades(fa)
      print ("son:" , conversion , "fardos")

      if op== "2":
        und = float(input("introduce numero de unidades:  "))
        conversion = unidades_a_fardo(und)
        print ("son:" , conversion , "unidades")
