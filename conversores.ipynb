# %%
def caja_a_unidad(ca):
  caja= 25 
  return ca

  def unidad_a_caja(un):
    unidad= 80
    return un

    print ("1 Converti cajas a unidesdes")
    print ("2 Convertir unidades a cajas")
    opcion = input ("-->")

    op = menu ()
    if op== "1":
      cjas = float(input("introduce numero de cajas:   "))
      conversion = cajas_a_unidad(cjas)
      print ("son:" , conversion , "unidades")

      if op== "2":
        und = float(input("introduce numero de unidades:  "))
        conversion = unidades_a_cajas(und)
        print ("son:" , conversion , "cajas")
